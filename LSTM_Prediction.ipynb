# %% [markdown]
# <a href="https://colab.research.google.com/github/Tommy840602/LSTM/blob/main/LSTM_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
import tensorflow as tf
from keras import Model
from keras.layers import Input, Dense, Dropout
from keras.layers import LSTM

# %%
df = pd.read_csv('/content/Gold Price (2013-2023).csv')
df.head()
# Out:
#          Date     Price      Open      High       Low     Vol. Change %
# 0  12/30/2022  1,826.20  1,821.80  1,832.40  1,819.80  107.50K    0.01%
# 1  12/29/2022  1,826.00  1,812.30  1,827.30  1,811.20  105.99K    0.56%
# 2  12/28/2022  1,815.80  1,822.40  1,822.80  1,804.20  118.08K   -0.40%
# 3  12/27/2022  1,823.10  1,808.20  1,841.90  1,808.00  159.62K    0.74%
# 4  12/26/2022  1,809.70  1,805.80  1,811.95  1,805.55      NaN    0.30%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2583 entries, 0 to 2582
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      2583 non-null   object
#  1   Price     2583 non-null   object
#  2   Open      2583 non-null   object
#  3   High      2583 non-null   object
#  4   Low       2583 non-null   object
#  5   Vol.      2578 non-null   object
#  6   Change %  2583 non-null   object
# dtypes: object(7)
# memory usage: 141.4+ KB

# %%
#Data Preparation

#Feature Subset Selection
df.drop(['Vol.','Change %'], axis=1, inplace=True)

# %%
#Transforming Data
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values(by='Date', ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

NumCols = df.columns.drop(['Date'])
df[NumCols] = df[NumCols].replace({',': ''}, regex=True)
df[NumCols] = df[NumCols].astype('float64')

# %%
df.head()
# Out:
#         Date   Price    Open    High     Low
# 0 2013-01-02  1689.9  1675.8  1695.0  1672.1
# 1 2013-01-03  1675.6  1688.0  1689.3  1664.3
# 2 2013-01-04  1649.9  1664.4  1664.4  1630.0
# 3 2013-01-07  1647.2  1657.3  1663.8  1645.3
# 4 2013-01-08  1663.2  1651.5  1662.6  1648.8

# %%
#Checking Duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#Checking Missing Values
df.isnull().sum().sum()
# Out:
# 0

# %%
#Visualizing Gold Price History Data
fig = px.line(y=df.Price, x=df.Date)
fig.update_traces(line_color='black')
fig.update_layout(xaxis_title="Date",
                  yaxis_title="Scaled Price",
                  title={'text': "Gold Price History Data", 'y':0.95, 'x':0.5, 'xanchor':'center', 'yanchor':'top'},
                  plot_bgcolor='white')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3f2d2125-b2cf-4a88-b8a0-12906c93691b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f2d2125-b2cf-4a88-b8a0-12906c93691b")) {                    Plotly.newPlot(                        "3f2d2125-b2cf-4a88-b8a0-12906c93691b",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"black","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-18T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-27T00:00:00","2013-05-28T00:00:00","2013-05-29T00:00:00","2013-05-30T00:00:00","2013-05-31T00:00:00","2013-06-03T00:00:00","2013-06-04T00:00:00","2013-06-05T00:00:00","2013-06-06T00:00:00","2013-06-07T00:00:00","2013-06-10T00:00:00","2013-06-11T00:00:00","2013-06-12T00:00:00","2013-06-13T00:00:00","2013-06-14T00:00:00","2013-06-17T00:00:00","2013-06-18T00:00:00","2013-06-19T00:00:00","2013-06-20T00:00:00","2013-06-21T00:00:00","2013-06-24T00:00:00","2013-06-25T00:00:00","2013-06-26T00:00:00","2013-06-27T00:00:00","2013-06-28T00:00:00","2013-07-01T00:00:00","2013-07-02T00:00:00","2013-07-03T00:00:00","2013-07-04T00:00:00","2013-07-05T00:00:00","2013-07-08T00:00:00","2013-07-09T00:00:00","2013-07-10T00:00:00","2013-07-11T00:00:00","2013-07-12T00:00:00","2013-07-15T00:00:00","2013-07-16T00:00:00","2013-07-17T00:00:00","2013-07-18T00:00:00","2013-07-19T00:00:00","2013-07-22T00:00:00","2013-07-23T00:00:00","2013-07-24T00:00:00","2013-07-25T00:00:00","20 ...

# %%
#Splitting Data to Training & Test Sets
test_size = df[df.Date.dt.year==2022].shape[0]
test_size
# Out:
# 260

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'white'
plt.rc('axes',edgecolor='white')
plt.plot(df.Date[:-test_size], df.Price[:-test_size], color='black', lw=2)
plt.plot(df.Date[-test_size:], df.Price[-test_size:], color='blue', lw=2)
plt.title('Gold Price Training and Test Sets', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training set', 'Test set'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()

# %%
#Data Scaling
scaler = MinMaxScaler()
scaler.fit(df.Price.values.reshape(-1,1))
# Out:
# MinMaxScaler()

# %%
#Restructure Data & Create Sliding Window
window_size = 60

# %%
#Training Set:
train_data = df.Price[:-test_size]
train_data = scaler.transform(train_data.values.reshape(-1,1))

X_train = []
y_train = []

for i in range(window_size, len(train_data)):
    X_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

# %%
#Test Set:
test_data = df.Price[-test_size-60:]
test_data = scaler.transform(test_data.values.reshape(-1,1))

X_test = []
y_test = []

for i in range(window_size, len(test_data)):
    X_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])

# %%
#Converting Data to Numpy Arrays
X_train = np.array(X_train)
X_test  = np.array(X_test)
y_train = np.array(y_train)
y_test  = np.array(y_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test  = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
y_train = np.reshape(y_train, (-1,1))
y_test  = np.reshape(y_test, (-1,1))

# %%
print('X_train Shape: ', X_train.shape)
print('y_train Shape: ', y_train.shape)
print('X_test Shape:  ', X_test.shape)
print('y_test Shape:  ', y_test.shape)
# Out:
# X_train Shape:  (2263, 60, 1)
# y_train Shape:  (2263, 1)
# X_test Shape:   (260, 60, 1)
# y_test Shape:   (260, 1)

# %%
#Creating an LSTM Network
def define_model():
    input1 = Input(shape=(window_size,1))
    x = LSTM(units = 64, return_sequences=True)(input1)
    x = Dropout(0.2)(x)
    x = LSTM(units = 64, return_sequences=True)(x)
    x = Dropout(0.2)(x)
    x = LSTM(units = 64)(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation='softmax')(x)
    dnn_output = Dense(1)(x)

    model = Model(inputs=input1, outputs=[dnn_output])
    model.compile(loss='mean_squared_error', optimizer='Nadam')
    model.summary()

    return model

# %%
model = define_model()
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 60, 1)]           0
#
#  lstm (LSTM)                 (None, 60, 64)            16896
#
#  dropout (Dropout)           (None, 60, 64)            0
#
#  lstm_1 (LSTM)               (None, 60, 64)            33024
#
#  dropout_1 (Dropout)         (None, 60, 64)            0
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 85057 (332.25 KB)
# Trainable params: 85057 (332.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/150
# 64/64 [==============================] - 9s 72ms/step - loss: 0.0483 - val_loss: 0.1054
# Epoch 2/150
# 64/64 [==============================] - 4s 63ms/step - loss: 0.0141 - val_loss: 0.0502
# Epoch 3/150
# 64/64 [==============================] - 5s 80ms/step - loss: 0.0085 - val_loss: 0.0239
# Epoch 4/150
# 64/64 [==============================] - 4s 65ms/step - loss: 0.0056 - val_loss: 0.0104
# Epoch 5/150
# 64/64 [==============================] - 4s 68ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 6/150
# 64/64 [==============================] - 4s 57ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 7/150
# 64/64 [==============================] - 6s 92ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 8/150
# 64/64 [==============================] - 5s 79ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 9/150
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0016 - val_loss: 0.0035
# Epoch 10/150
# 64/64 [==============================] - 6s 90ms/step - loss: 0.0014 - val_loss: 0.0064
# Epoch 11/150
# 64/64 [==============================] - 4s 63ms/step - loss: 0.0013 - val_loss: 0.0060
# Epoch 12/150
# 64/64 [==============================] - 4s 57ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 13/150
# 64/64 [==============================] - 5s 80ms/step - loss: 0.0012 - val_loss: 0.0076
# Epoch 14/150
# 64/64 [==============================] - 4s 67ms/step - loss: 0.0011 - val_loss: 0.0056
# Epoch 15/150
# 64/64 [==============================] - 4s 58ms/step - loss: 0.0011 - val_loss: 0.0052
# Epoch 16/150
# 64/64 [==============================] - 4s 64ms/step - loss: 0.0010 - val_loss: 0.0043
# Epoch 17/150
# 64/64 [==============================] - 4s 58ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 18/150
# 64/64 [==============================] - 4s 58ms/step - loss: 9.5332e-04 - val_loss: 0.0034
# Epoch 19/150
# 64/64 [==============================] - 4s 64ms/step - loss: 9.5858e-04 - val_loss: 0.0011
# Epoch 20/150
# 64/64 [==============================] - 4s 58ms/step - loss: 8.5307e-04 - val_loss: 0.0014
# Epoch 21/150
# 64/64 [==============================] - 4s 58ms/step - loss: 9.2026e-04 - val_loss: 0.0015
# Epoch 22/150
# 64/64 [==============================] - 4s 70ms/step - loss: 8.2816e-04 - val_loss: 0.0057
# Epoch 23/150
# 64/64 [==============================] - 4s 59ms/step - loss: 7.7707e-04 - val_loss: 8.2128e-04
# Epoch 24/150
# 64/64 [==============================] - 4s 58ms/step - loss: 7.6071e-04 - val_loss: 9.6723e-04
# Epoch 25/150
# 64/64 [==============================] - 4s 64ms/step - loss: 7.1706e-04 - val_loss: 0.0029
# Epoch 26/150
# 64/64 [==============================] - 4s 58ms/step - loss: 6.6913e-04 - val_loss: 0.0037
# Epoch 27/150
# 64/64 [==============================] - 4s 58ms/step - loss: 7.2212e-04 - val_loss: 0.0025
# Epoch 28/150
# 64/64 [==============================] - 4s 64ms/step - loss: 6.7014e-04 - val_loss: 7.3099e-04
# Epoch 29/150
# 64/64 [==============================] - 4s 57ms/step - loss: 6.2007e-04 - val_loss: 0.0018
# Epoch 30/150
# 64/64 [==============================] - 4s 58ms/step - loss: 6.7631e-04 - val_loss: 0.0011
# Epoch 31/150
# 64/64 [==============================] - 4s 64ms/step - loss: 6.7452e-04 - val_loss: 0.0019
# Epoch 32/150
# 64/64 [==============================] - 4s 57ms/step - loss: 6.3230e-04 - val_loss: 0.0011
# Epoch 33/150
# 64/64 [==============================] - 5s 71ms/step - loss: 6.5614e-04 - val_loss: 0.0013
# Epoch 34/150
# 64/64 [==============================] - 4s 66ms/step - loss: 6.0086e-04 - val_loss: 0.0019
# Epoch 35/150
# 64/64 [==============================] - 4s 57ms/step - loss: 5.9930e-04 - val_loss: 0.0013
# Epoch 36/150
# 64/64 [==============================] - 4s 63ms/step - loss: 6.4345e-04 - val_loss: 8.7822e-04
# Epoch 37/150
# 64/64 [==============================] - 4s 57ms/step - loss: 5.8585e-04 - val_loss: 5.8594e-04
# Epoch 38/150
# 64/64 [==============================] - 4s 58ms/step - loss: 6.1650e-04 - val_loss: 6.9290e-04
# Epoch 39/150
# 64/64 [==============================] - 4s 64ms/step - loss: 5.6690e-04 - val_loss: 5.4802e-04
# Epoch 40/150
# 64/64 [==============================] - 4s 57ms/step - loss: 5.5711e-04 - val_loss: 6.1893e-04
# Epoch 41/150
# 64/64 [==============================] - 4s 58ms/step - loss: 5.5253e-04 - val_loss: 6.3473e-04
# Epoch 42/150
# 64/64 [==============================] - 4s 64ms/step - loss: 5.3842e-04 - val_loss: 0.0011
# Epoch 43/150
# 64/64 [==============================] - 4s 62ms/step - loss: 5.2723e-04 - val_loss: 0.0014
# Epoch 44/150
# 64/64 [==============================] - 4s 58ms/step - loss: 5.2444e-04 - val_loss: 9.4755e-04
# Epoch 45/150
# 64/64 [==============================] - 6s 93ms/step - loss: 5.0336e-04 - val_loss: 0.0011
# Epoch 46/150
# 64/64 [==============================] - 4s 64ms/step - loss: 4.8380e-04 - val_loss: 0.0011
# Epoch 47/150
# 64/64 [==============================] - 4s 60ms/step - loss: 5.0290e-04 - val_loss: 6.8173e-04
# Epoch 48/150
# 64/64 [==============================] - 4s 68ms/step - loss: 5.3401e-04 - val_loss: 7.4416e-04
# Epoch 49/150
# 64/64 [==============================] - 4s 62ms/step - loss: 5.0889e-04 - val_loss: 0.0014
# Epoch 50/150
# 64/64 [==============================] - 4s 63ms/step - loss: 5.1761e-04 - val_loss: 4.4618e-04
# Epoch 51/150
# 64/64 [==============================] - 4s 63ms/step - loss: 5.0824e-04 - val_loss: 8.3082e-04
# Epoch 52/150
# 64/64 [==============================] - 4s 60ms/step - loss: 4.7547e-04 - val_loss: 7.4847e-04
# Epoch 53/150
# 64/64 [==============================] - 4s 66ms/step - loss: 4.6667e-04 - val_loss: 4.6828e-04
# Epoch 54/150
# 64/64 [==============================] - 4s 59ms/step - loss: 4.8758e-04 - val_loss: 5.1670e-04
# Epoch 55/150
# 64/64 [==============================] - 4s 59ms/step - loss: 4.4575e-04 - val_loss: 8.7147e-04
# Epoch 56/150
# 64/64 [==============================] - 4s 65ms/step - loss: 4.2707e-04 - val_loss: 5.5119e-04
# Epoch 57/150
# 64/64 [==============================] - 4s 58ms/step - loss: 4.4407e-04 - val_loss: 0.0017
# Epoch 58/150
# 64/64 [==============================] - 4s 59ms/step - loss: 4.5304e-04 - val_loss: 5.8311e-04
# Epoch 59/150
# 64/64 [==============================] - 4s 67ms/step - loss: 4.3291e-04 - val_loss: 4.2795e-04
# Epoch 60/150
# 64/64 [==============================] - 4s 66ms/step - loss: 4.2333e-04 - val_loss: 7.8588e-04
# Epoch 61/150
# 64/64 [==============================] - 4s 60ms/step - loss: 4.3921e-04 - val_loss: 0.0017
# Epoch 62/150
# 64/64 [==============================] - 4s 67ms/step - loss: 4.5508e-04 - val_loss: 6.2537e-04
# Epoch 63/150
# 64/64 [==============================] - 4s 60ms/step - loss: 4.3765e-04 - val_loss: 4.7459e-04
# Epoch 64/150
# 64/64 [==============================] - 4s 59ms/step - loss: 4.2032e-04 - val_loss: 8.0356e-04
# Epoch 65/150
# 64/64 [==============================] - 4s 64ms/step - loss: 4.0852e-04 - val_loss: 8.0470e-04
# Epoch 66/150
# 64/64 [==============================] - 4s 59ms/step - loss: 4.2121e-04 - val_loss: 0.0019
# Epoch 67/150
# 64/64 [==============================] - 4s 63ms/step - loss: 4.0862e-04 - val_loss: 7.8587e-04
# Epoch 68/150
# 64/64 [==============================] - 4s 61ms/step - loss: 4.0716e-04 - val_loss: 0.0013
# Epoch 69/150
# 64/64 [==============================] - 4s 59ms/step - loss: 4.1229e-04 - val_loss: 7.2394e-04
# Epoch 70/150
# 64/64 [==============================] - 4s 65ms/step - loss: 4.0880e-04 - val_loss: 0.0016
# Epoch 71/150
# 64/64 [==============================] - 4s 59ms/step - loss: 4.0128e-04 - val_loss: 4.8228e-04
# Epoch 72/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.9051e-04 - val_loss: 0.0012
# Epoch 73/150
# 64/64 [==============================] - 4s 66ms/step - loss: 4.0035e-04 - val_loss: 7.7375e-04
# Epoch 74/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.9268e-04 - val_loss: 3.9518e-04
# Epoch 75/150
# 64/64 [==============================] - 4s 60ms/step - loss: 4.3308e-04 - val_loss: 5.0451e-04
# Epoch 76/150
# 64/64 [==============================] - 4s 67ms/step - loss: 4.0002e-04 - val_loss: 7.8495e-04
# Epoch 77/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.6563e-04 - val_loss: 4.5017e-04
# Epoch 78/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.7399e-04 - val_loss: 4.6330e-04
# Epoch 79/150
# 64/64 [==============================] - 4s 66ms/step - loss: 3.8445e-04 - val_loss: 4.6241e-04
# Epoch 80/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.9887e-04 - val_loss: 6.5140e-04
# Epoch 81/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.7699e-04 - val_loss: 0.0011
# Epoch 82/150
# 64/64 [==============================] - 4s 66ms/step - loss: 3.9956e-04 - val_loss: 5.9524e-04
# Epoch 83/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.6962e-04 - val_loss: 0.0020
# Epoch 84/150
# 64/64 [==============================] - 4s 62ms/step - loss: 3.7615e-04 - val_loss: 8.5558e-04
# Epoch 85/150
# 64/64 [==============================] - 4s 61ms/step - loss: 3.7719e-04 - val_loss: 0.0028
# Epoch 86/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.5766e-04 - val_loss: 5.3328e-04
# Epoch 87/150
# 64/64 [==============================] - 4s 65ms/step - loss: 3.6847e-04 - val_loss: 5.7478e-04
# Epoch 88/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.8195e-04 - val_loss: 6.7125e-04
# Epoch 89/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.5342e-04 - val_loss: 0.0030
# Epoch 90/150
# 64/64 [==============================] - 4s 66ms/step - loss: 4.2130e-04 - val_loss: 9.4664e-04
# Epoch 91/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.7916e-04 - val_loss: 0.0013
# Epoch 92/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.5941e-04 - val_loss: 0.0015
# Epoch 93/150
# 64/64 [==============================] - 4s 67ms/step - loss: 3.3864e-04 - val_loss: 8.8413e-04
# Epoch 94/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.3955e-04 - val_loss: 0.0017
# Epoch 95/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.4169e-04 - val_loss: 5.2640e-04
# Epoch 96/150
# 64/64 [==============================] - 4s 66ms/step - loss: 3.3574e-04 - val_loss: 9.1367e-04
# Epoch 97/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.4529e-04 - val_loss: 0.0011
# Epoch 98/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.8971e-04 - val_loss: 7.9458e-04
# Epoch 99/150
# 64/64 [==============================] - 4s 66ms/step - loss: 3.4219e-04 - val_loss: 0.0012
# Epoch 100/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.4258e-04 - val_loss: 4.4070e-04
# Epoch 101/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.3108e-04 - val_loss: 0.0013
# Epoch 102/150
# 64/64 [==============================] - 4s 65ms/step - loss: 3.3704e-04 - val_loss: 6.8738e-04
# Epoch 103/150
# 64/64 [==============================] - 4s 61ms/step - loss: 3.6542e-04 - val_loss: 0.0011
# Epoch 104/150
# 64/64 [==============================] - 4s 65ms/step - loss: 3.7078e-04 - val_loss: 0.0018
# Epoch 105/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.5382e-04 - val_loss: 0.0016
# Epoch 106/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.4697e-04 - val_loss: 0.0020
# Epoch 107/150
# 64/64 [==============================] - 4s 66ms/step - loss: 3.2953e-04 - val_loss: 0.0017
# Epoch 108/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.4585e-04 - val_loss: 0.0011
# Epoch 109/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.4481e-04 - val_loss: 0.0018
# Epoch 110/150
# 64/64 [==============================] - 4s 66ms/step - loss: 3.2879e-04 - val_loss: 9.6310e-04
# Epoch 111/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.2611e-04 - val_loss: 8.1751e-04
# Epoch 112/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.3830e-04 - val_loss: 0.0010
# Epoch 113/150
# 64/64 [==============================] - 4s 68ms/step - loss: 3.6049e-04 - val_loss: 9.9766e-04
# Epoch 114/150
# 64/64 [==============================] - 4s 64ms/step - loss: 3.2416e-04 - val_loss: 5.8173e-04
# Epoch 115/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.2190e-04 - val_loss: 0.0010
# Epoch 116/150
# 64/64 [==============================] - 4s 65ms/step - loss: 3.2497e-04 - val_loss: 0.0014
# Epoch 117/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.5442e-04 - val_loss: 7.3845e-04
# Epoch 118/150
# 64/64 [==============================] - 4s 61ms/step - loss: 3.2619e-04 - val_loss: 9.7795e-04
# Epoch 119/150
# 64/64 [==============================] - 4s 64ms/step - loss: 3.3107e-04 - val_loss: 0.0016
# Epoch 120/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.2966e-04 - val_loss: 7.2641e-04
# Epoch 121/150
# 64/64 [==============================] - 4s 65ms/step - loss: 2.9064e-04 - val_loss: 7.8392e-04
# Epoch 122/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.3047e-04 - val_loss: 8.9961e-04
# Epoch 123/150
# 64/64 [==============================] - 4s 61ms/step - loss: 3.2206e-04 - val_loss: 0.0021
# Epoch 124/150
# 64/64 [==============================] - 4s 66ms/step - loss: 3.0388e-04 - val_loss: 0.0012
# Epoch 125/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.2467e-04 - val_loss: 0.0017
# Epoch 126/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.3432e-04 - val_loss: 0.0014
# Epoch 127/150
# 64/64 [==============================] - 4s 66ms/step - loss: 3.2120e-04 - val_loss: 0.0014
# Epoch 128/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.3946e-04 - val_loss: 0.0013
# Epoch 129/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.1989e-04 - val_loss: 0.0012
# Epoch 130/150
# 64/64 [==============================] - 4s 67ms/step - loss: 3.0555e-04 - val_loss: 0.0037
# Epoch 131/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.4030e-04 - val_loss: 0.0016
# Epoch 132/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.1044e-04 - val_loss: 6.8332e-04
# Epoch 133/150
# 64/64 [==============================] - 4s 65ms/step - loss: 3.1819e-04 - val_loss: 9.0430e-04
# Epoch 134/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.0904e-04 - val_loss: 5.8465e-04
# Epoch 135/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.2011e-04 - val_loss: 0.0015
# Epoch 136/150
# 64/64 [==============================] - 4s 66ms/step - loss: 2.9451e-04 - val_loss: 0.0014
# Epoch 137/150
# 64/64 [==============================] - 4s 61ms/step - loss: 3.1022e-04 - val_loss: 9.5200e-04
# Epoch 138/150
# 64/64 [==============================] - 4s 66ms/step - loss: 3.1026e-04 - val_loss: 8.5397e-04
# Epoch 139/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.1707e-04 - val_loss: 6.3450e-04
# Epoch 140/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.1134e-04 - val_loss: 8.7790e-04
# Epoch 141/150
# 64/64 [==============================] - 4s 66ms/step - loss: 3.0177e-04 - val_loss: 0.0015
# Epoch 142/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.1434e-04 - val_loss: 0.0019
# Epoch 143/150
# 64/64 [==============================] - 4s 60ms/step - loss: 2.9753e-04 - val_loss: 0.0014
# Epoch 144/150
# 64/64 [==============================] - 4s 66ms/step - loss: 3.0029e-04 - val_loss: 7.2963e-04
# Epoch 145/150
# 64/64 [==============================] - 4s 59ms/step - loss: 3.0864e-04 - val_loss: 0.0012
# Epoch 146/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.0599e-04 - val_loss: 0.0011
# Epoch 147/150
# 64/64 [==============================] - 4s 66ms/step - loss: 3.0607e-04 - val_loss: 0.0012
# Epoch 148/150
# 64/64 [==============================] - 4s 60ms/step - loss: 3.1492e-04 - val_loss: 8.0656e-04
# Epoch 149/150
# 64/64 [==============================] - 4s 59ms/step - loss: 2.8800e-04 - val_loss: 0.0010
# Epoch 150/150
# 64/64 [==============================] - 4s 66ms/step - loss: 3.1518e-04 - val_loss: 8.2095e-04

# %%
#Model Evaluation
result = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
# Out:
# 9/9 [==============================] - 0s 15ms/step - loss: 6.8532e-04
# 9/9 [==============================] - 1s 15ms/step

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
Accuracy = 1 - MAPE

# %%
print("Test Loss:", result)
print("Test MAPE:", MAPE)
print("Test Accuracy:", Accuracy)
# Out:
# Test Loss: 0.000685323029756546
# Test MAPE: 0.028567150465056104
# Test Accuracy: 0.9714328495349439

# %%
#Visualizing Results
y_test_true = scaler.inverse_transform(y_test)
y_test_pred = scaler.inverse_transform(y_pred)

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'white'
plt.rc('axes',edgecolor='white')
plt.plot(df['Date'].iloc[:-test_size], scaler.inverse_transform(train_data), color='black', lw=2)
plt.plot(df['Date'].iloc[-test_size:], y_test_true, color='blue', lw=2)
plt.plot(df['Date'].iloc[-test_size:], y_test_pred, color='red', lw=2)
plt.title('Model Performance on Gold Price Prediction', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training Data', 'Actual Test Data', 'Predicted Test Data'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()
